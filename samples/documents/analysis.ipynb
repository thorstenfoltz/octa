# %% [markdown]
# # Menu analysis
#
# Octa opens a notebook in its own view: markdown cells render, code
# cells keep their syntax colouring, and existing outputs are preserved
# when you edit a source cell and save.

# %%
import csv
rows = list(csv.DictReader(open('../tables/products.csv')))
print(len(rows), 'products')
# Out:
# 8 products

# %%
sum(float(r['price']) for r in rows) / len(rows)
# Out:
# 3.20625

# %% [markdown]
# The average price is what you would expect for a place that
# sells more coffee than cake.
